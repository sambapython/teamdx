# %%
import data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import data
#
# ModuleNotFoundError: No module named 'data'

# %%
f=open('data.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 f=open('data.txt')
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data.txt'

# %%
f=open('data.txt')

# %%
print(dir(f))
# Out:
# ['_CHUNK_SIZE', '__class__', '__del__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_checkClosed', '_checkReadable', '_checkSeekable', '_checkWritable', '_finalizing', 'buffer', 'close', 'closed', 'detach', 'encoding', 'errors', 'fileno', 'flush', 'isatty', 'line_buffering', 'mode', 'name', 'newlines', 'read', 'readable', 'readline', 'readlines', 'reconfigure', 'seek', 'seekable', 'tell', 'truncate', 'writable', 'write', 'write_through', 'writelines']

# %%
data=f.read()

# %%
print(data)
# Out:
# name,age,sal
# Anil,23,2345678
# Ajay,25,2435767

# %%
print(type(data))
# Out:
# <class 'str'>

# %%
data1=f.read()

# %%
print(data1)

# %%
f.close()

# %%
f=open("data.txt")

# %%
print(f.tell())
# Out:
# 0

# %%
data = f.read()

# %%
print(data)
# Out:
# name,age,sal
# Anil,23,2345678
# Ajay,25,2435767

# %%
print(f.tell())
# Out:
# 48

# %%
f.seek(0)
# Out:
# 0

# %%
print(f.tell())
# Out:
# 0

# %%
f.close()

# %%
f=open("data.txt")
print(f.tell())
data=f.read(12)
print(data)
print(f.tell())
# Out:
# 0
# name,age,sal
# 12

# %%
data1=f.read(12)
print(data1)
print(f.tell())
# Out:
# Anil,23,234
# 25

# %%
data2=f.read(12)
print(data2)
print(f.tell())
# Out:
# 5678
# Ajay,25
# 38

# %%
data2=f.read(12)
print(data2)
print(f.tell())
# Out:
# ,2435767
#
# 48

# %%
data2=f.read(12)
print(data2)
print(f.tell())
# Out:
# 48

# %%
f.close()

# %%
f=open('data.txt')
for row in f:
    print(row)
f.close()
# Out:
# name,age,sal
#
# Anil,23,2345678
#
# Ajay,25,2435767

# %%
f=open('data.txt')
for row in f:
    print(row)
    print("*"*20)
f.close()
# Out:
# name,age,sal
#
# ********************
# Anil,23,2345678
#
# ********************
# Ajay,25,2435767
#
# ********************

# %%
f=open('data.txt')
for row in f:
    print(row)
    print(row.split(","))
    print("*"*20)
f.close()
# Out:
# name,age,sal
#
# ['name', 'age', 'sal\n']
# ********************
# Anil,23,2345678
#
# ['Anil', '23', '2345678\n']
# ********************
# Ajay,25,2435767
#
# ['Ajay', '25', '2435767\n']
# ********************

# %%
f=open('data.txt')
for row in f:
    print(row)
    print(row.split(",")[-1])
    print("*"*20)
f.close()
# Out:
# name,age,sal
#
# sal
#
# ********************
# Anil,23,2345678
#
# 2345678
#
# ********************
# Ajay,25,2435767
#
# 2435767
#
# ********************

# %%
f=open('data.txt')
for row in f:
    print(row.split(",")[-1].strip())
    print("*"*20)
f.close()
# Out:
# sal
# ********************
# 2345678
# ********************
# 2435767
# ********************

# %%
f=open('data.txt')
for row in f:
    print(row.split(",")[-1])
    print("*"*20)
f.close()
# Out:
# sal
#
# ********************
# 2345678
#
# ********************
# 2435767
#
# ********************

# %%
f=open('data.txt')
sals=[]
for row in f:
    sals.append(row.split(",")[-1].strip())
f.close()
print(sals)
# Out:
# ['sal', '2345678', '2435767']

# %%
f=open('data.txt')
first_line = f.readline()# reading first line because it's a column names
sals=[]
for row in f:
    sals.append(row.split(",")[-1].strip())
f.close()
print(sals)
# Out:
# ['2345678', '2435767']

# %%
f=open('data.txt')
first_line = f.readline()# reading first line because it's a column names
sals=[]
for row in f:
    sals.append(row.split(",")[-1].strip())
f.close()
l=[1,2,3,4]
print(sum(l))
# Out:
# 10

# %%
f=open('data.txt')
first_line = f.readline()# reading first line because it's a column names
sals=[]
for row in f:
    sals.append(row.split(",")[-1].strip())
f.close()
print(sals)
print(sum(sals))
# Out:
# ['2345678', '2435767']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 8
#       6 f.close()
#       7 print(sals)
# ----> 8 print(sum(sals))
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
f=open('data.txt')
first_line = f.readline()# reading first line because it's a column names
sals=[]
for row in f:
    sals.append(int(row.split(",")[-1].strip()))
f.close()
print(sals)
print(sum(sals))
# Out:
# [2345678, 2435767]
# 4781445

# %%
f=open('data.txt')
data = f.readlines()
print(data)
# Out:
# ['name,age,sal\n', 'Anil,23,2345678\n', 'Ajay,25,2435767\n']

# %%
#what is your ram size? 8GB... 10GB

# %%
f=open("BIGFILE.txt","w")

# %%
f.write("name,age,sal\n")
f.write("Anil,23,2343245325\n")
# Out:
# 19

# %%
len("Anil,23,2343245325\n")
# Out:
# 19

# %%
f.flush()

# %%
f.write("Ajay,24,32432532\n")
# Out:
# 17

# %%
f.close()

# %%
f.write("sadsa")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 f.write("sadsa")
#
# ValueError: I/O operation on closed file.

# %%
import faker

# %%
from faker import Faker

# %%
faker = Faker()

# %%
faker.name()
# Out:
# 'Meagan Bailey'

# %%
from random import randint

# %%
print(dir(randint))
# Out:
# ['__call__', '__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__func__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__self__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__']

# %%
randint(12,34)
# Out:
# 15

# %%
randint(12,34)
# Out:
# 23

# %%
randint(12,34)
# Out:
# 26

# %%
randint(12,34)
# Out:
# 29

# %%
randint(12,34)
# Out:
# 15

# %%
from faker import Faker
from random import randint
fake=Faker()
f=open("BIGFILE.txt","w")
for i in range(1000):
    row = f"{fake.name()},{randint(23,60)},{randint(4000000,9000000)}\n"
    print(row)
    break
f.close()
# Out:
# David Rios,36,8763257

# %%
from faker import Faker
from random import randint
fake=Faker()
f=open("BIGFILE.txt","w")
for i in range(1000):
    row = f"{fake.name()},{randint(23,60)},{randint(4000000,9000000)}\n"
    f.write(row)
    f.flush()
f.close()

# %%
#sum of salaries
#top ten salaried employee names.
# how many number employees are taking salaries more than average salary
